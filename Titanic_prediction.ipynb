# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaviyashreepalraj/KsB-files/blob/main/Titanic_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt # Import the matplotlib library

data = pd.read_csv('Titanic-Dataset.csv')
print(data)
data.head()
data.sample(10)
data.columns
data.shape
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='PassengerId', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Passenger Id')
plt.ylabel('Survival Rate')
plt.xlabel('Passenger Rate')
plt.show()
# Out:
# <ipython-input-42-69afb1b7b449>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='PassengerId', y='Survived', data=data, ci=None)

# %%
sns.scatterplot(x='Fare', y='Ticket', hue='Sex', data=data) # Changed hue to 'Sex' as it exists in the dataset
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt # Import the matplotlib library

data = pd.read_csv('Titanic-Dataset.csv')

data.hist(color= 'violet' ,edgecolor='black',figsize=(10,10))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.plot.hist(subplots=True, layout=(3,3), figsize=(10, 10), bins=20) # Changed layout to (3,3plt.show()
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>]], dtype=object)

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Sex') # Changed to countplot as it seems like you want to count the occurrences of each gender
plt.title('Count Plot for age Column')
plt.xlabel('age')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'data' is a pandas DataFrame where one column contains numerical data
plt.figure(figsize=[5, 3])
# Choose a numerical column for plotting
numerical_column = 'Age'  # Replace with the actual column name
plt.plot(data.index, data[numerical_column], label=numerical_column)
plt.xlabel('Index')  # Or any appropriate label for the x-axis
plt.ylabel(numerical_column)
plt.legend()
plt.show()

# %%
# !pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you want to drop all non-numeric columns
numeric_data = data.select_dtypes(include=['number'])
sns.boxplot(data=numeric_data)
plt.show()

# %%
import pandas as pd
import seaborn as sns


data = pd.read_csv('Titanic-Dataset.csv')
numerical_cols = ['Age', 'SibSp', 'Parch', 'Fare']

data["total_values"] = data[numerical_cols].sum(axis=1)
newcols = {"PassengerId": "id", "Survived": "survived"}
data.rename(columns=newcols, inplace=True)
print(data.head())
# Out:
#    id  survived  Pclass                                               Name  \
# 0   1         0       3                            Braund, Mr. Owen Harris
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
# 3   4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4   5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    total_values
# 0       30.2500
# 1      110.2833
# 2       33.9250
# ...
