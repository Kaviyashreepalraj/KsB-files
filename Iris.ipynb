# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaviyashreepalraj/KsB-files/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('IRIS.csv')
print(data)
data.head()
data.sample(10)
data.columns
data.shape
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt # Import the matplotlib library

data = pd.read_csv('IRIS.csv')
print(data)
data.head()
data.sample(10)
data.columns
data.shape
print(data)

data.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
plt.show() # Now you can use data in this cell
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
# Select only the numerical columns for correlation calculation
numerical_data = data.select_dtypes(include=['number'])

sns.heatmap(numerical_data.corr(), annot=True)  # Note: 'False' should be 'True' for annotations
plt.show()

# %%
data.hist(color= 'pink' ,edgecolor='yellow',figsize=(10,10)) # Replace 'mediumpink' with a valid Matplotlib color like 'pink'
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame and 'species' is a column in it
sns.pairplot(data, hue='species')  # Replace 'species' with the actual column name if different
plt.show()

# %%
Nisns.scatterplot(x='petal_length', y='petal_width', hue='species', data=data)
plt.show()

# %%
sns.boxplot(data=data.drop(['species'], axis=1))
plt.show()

# %%
import pandas as pd
import seaborn as sns

# Load the iris dataset
data = pd.read_csv('IRIS.csv')

# Select numerical columns for summation
numerical_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# Calculate the sum of numerical columns
data["total_values"] = data[numerical_cols].sum(axis=1)

# Rename columns if needed
newcols = {"Id": "id", "sepal_length": "sepal_length", "sepal_width": "sepal_width"}
data.rename(columns=newcols, inplace=True)

# Print the head of the DataFrame
print(data.head())

# Styling and other operations can be performed as needed...
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    total_values
# 0          10.2
# 1           9.5
# 2           9.4
# 3           9.4
# 4          10.2

# %%
import pandas as pd
data = pd.read_csv('IRIS.csv')
print(data)
data.head()
data.sample(10)
print(data.columns) # Print columns to verify their names
data.shape
print(data)

print(data[10:21])
sliced_data=data[10:21]
print(sliced_data)
# Correct column names if necessary, they are likely lowercase and may contain spaces
specific_data=data[["sepal_length","species"]]
print(specific_data.head(10))
data.iloc[5]
data.loc[data["species"] == "Iris-setosa"]
data["species"].value_counts()
sum_data = data["sepal_length"].sum()
mean_data = data["sepal_length"].mean()
median_data = data["sepal_length"].median()
print("Sum:",sum_data, "\n mean:", mean_data, "\n median:",median_data)
min_data=data["sepal_length"].min()
max_data=data["sepal_length"].max()
print("Minimum:",min_data, "\n maximum:", max_data)
cols = data.columns
print(cols)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...
